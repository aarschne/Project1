# %%
import requests
from api_keys import nasdaq_api_key
from api_keys import alpha_vantage_api_key
import pprint as pp

# %%
# First test of using nasdaq api
#url = f"https://data.nasdaq.com/api/v3/datasets/wiki/FB.json?column_index=4&start_date=2014-01-01&end_date=2014-12-31&collapse=monthly&transform=rdiff&api_key={nasdaq_api_key}"
url = f"https://data.nasdaq.com/api/v3/datasets/FRED/CUUR0000SAF112.json?column_index=4&start_date=2014-01-01&end_date=2014-12-31&collapse=monthly&transform=rdiff&api_key={nasdaq_api_key}"


response = requests.get(url).json()

pp.pprint(response)
# Out:
# {'dataset': {'collapse': 'monthly',
#              'column_index': 4,
#              'column_names': ['Date', None],
#              'data': [],
#              'database_code': 'FRED',
#              'database_id': 118,
#              'dataset_code': 'CUUR0000SAF112',
#              'description': 'Index 1982-84=100 Not Seasonally Adjusted,  ',
#              'end_date': '2014-12-31',
#              'frequency': 'monthly',
#              'id': 124078,
#              'limit': None,
#              'name': 'Consumer Price Index for All Urban Consumers: Meats, '
#                      'poultry, fish, and eggs',
#              'newest_available_date': '2022-01-01',
#              'oldest_available_date': '1967-01-01',
#              'order': None,
#              'premium': False,
#              'refreshed_at': '2022-02-13T04:14:02.895Z',
#              'start_date': '2014-01-01',
#              'transform': 'rdiff',
#              'type': 'Time Series'}}

# %%
# Try finding egg price for the world
#url = f"https://data.nasdaq.com/api/v3/datatables/WASDE/DATA?code=EGGS_US_33&report_month=2023-04&api_key={nasdaq_api_key}"

#&start_date=2014-01-01&end_date=2014-12-31

response2 = requests.get(url).json()

pp.pprint(response2)
# Out:
# {'dataset': {'collapse': 'monthly',
#              'column_index': 4,
#              'column_names': ['Date', None],
#              'data': [],
#              'database_code': 'FRED',
#              'database_id': 118,
#              'dataset_code': 'CUUR0000SAF112',
#              'description': 'Index 1982-84=100 Not Seasonally Adjusted,  ',
#              'end_date': '2014-12-31',
#              'frequency': 'monthly',
#              'id': 124078,
#              'limit': None,
#              'name': 'Consumer Price Index for All Urban Consumers: Meats, '
#                      'poultry, fish, and eggs',
#              'newest_available_date': '2022-01-01',
#              'oldest_available_date': '1967-01-01',
#              'order': None,
#              'premium': False,
#              'refreshed_at': '2022-02-13T04:14:02.895Z',
#              'start_date': '2014-01-01',
#              'transform': 'rdiff',
#              'type': 'Time Series'}}

# %%
# Try finding apple stock information
url_apple = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=AAPL&outputsize=full&apikey={alpha_vantage_api_key}'
r_apple = requests.get(url_apple)
data_apple = r_apple.json()
data_apple
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-05-09',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-05-09': {'1. open': '173.05',
#    '2. high': '173.54',
#    '3. low': '171.6',
#    '4. close': '171.77',
#    '5. adjusted close': '171.77',
#    '6. volume': '45326874',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-08': {'1. open': '172.48',
#    '2. high': '173.85',
#    '3. low': '172.11',
#    '4. close': '173.5',
#    '5. adjusted close': '173.5',
#    '6. volume': '55962793',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-05': {'1. open': '170.975',
#    '2. high': '174.3',
#    '3. low': '170.76',
#    '4. close': '173.57',
#    '5. adjusted close': '173.57',
#    '6. volume': '113453171',
#    '7. dividend amount': '0.0000',
# ...

# %%
# Try finding motorola stock information
url_motorola = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=MSI&outputsize=full&apikey={alpha_vantage_api_key}'
r_motorola = requests.get(url_motorola)
data_motorola = r_motorola.json()
data_motorola
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'MSI',
#   '3. Last Refreshed': '2023-05-09',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-05-09': {'1. open': '284.53',
#    '2. high': '287.13',
#    '3. low': '283.92',
#    '4. close': '286.57',
#    '5. adjusted close': '286.57',
#    '6. volume': '590257',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-08': {'1. open': '284.01',
#    '2. high': '287.16',
#    '3. low': '282.8',
#    '4. close': '284.9',
#    '5. adjusted close': '284.9',
#    '6. volume': '1096083',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-05': {'1. open': '285.12',
#    '2. high': '288.86',
#    '3. low': '276.98',
#    '4. close': '281.56',
#    '5. adjusted close': '281.56',
#    '6. volume': '1501288',
#    '7. dividend amount': '0.0000',
# ...

# %%
# Try finding alphabet class c stock information
url_goog_c = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=GOOG&outputsize=full&apikey={alpha_vantage_api_key}'
r_goog_c = requests.get(url_goog_c)
data_goog_c = r_goog_c.json()
data_goog_c
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'GOOG',
#   '3. Last Refreshed': '2023-05-09',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-05-09': {'1. open': '108.78',
#    '2. high': '110.595',
#    '3. low': '107.725',
#    '4. close': '107.94',
#    '5. adjusted close': '107.94',
#    '6. volume': '24782442',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-08': {'1. open': '105.795',
#    '2. high': '108.42',
#    '3. low': '105.79',
#    '4. close': '108.24',
#    '5. adjusted close': '108.24',
#    '6. volume': '17266021',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-05': {'1. open': '105.32',
#    '2. high': '106.44',
#    '3. low': '104.7386',
#    '4. close': '106.215',
#    '5. adjusted close': '106.215',
#    '6. volume': '20710627',
#    '7. dividend amount': '0.0000',
# ...

# %%
# Try finding alphabet class a stock information
url_goog_a = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=GOOGL&outputsize=full&apikey={alpha_vantage_api_key}'
r_goog_a = requests.get(url_goog_a)
data_goog_a = r_goog_a.json()
data_goog_a
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'GOOGL',
#   '3. Last Refreshed': '2023-05-09',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2023-05-09': {'1. open': '108.39',
#    '2. high': '110.15',
#    '3. low': '107.19',
#    '4. close': '107.35',
#    '5. adjusted close': '107.35',
#    '6. volume': '36360141',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-08': {'1. open': '105.18',
#    '2. high': '107.96',
#    '3. low': '105.16',
#    '4. close': '107.77',
#    '5. adjusted close': '107.77',
#    '6. volume': '26511445',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-05-05': {'1. open': '104.82',
#    '2. high': '105.88',
#    '3. low': '104.11',
#    '4. close': '105.57',
#    '5. adjusted close': '105.57',
#    '6. volume': '26639254',
#    '7. dividend amount': '0.0000',
# ...
